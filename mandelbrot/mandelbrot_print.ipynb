# %%
import numpy as np
from mandelbrot import mandelbrot_set
from PIL import Image 
from matplotlib import cm
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
params = {
    'figure.figsize': (11,28),
}
plt.rcParams.update(params)

# %%
width, height = 1920, 1080
xmin, xmax, ymin, ymax = -2.0,0.5,-1.25,1.25
maxiter = 512

mandelbrot = mandelbrot_set(xmin, xmax, ymin, ymax, width, height, maxiter, method='parallel')

# %%
im = Image.fromarray(np.uint8(cm.gist_earth(mandelbrot)*255))

# %%
plt.axis('off')
plt.imshow(im)

# %%
im.save('mandelbrot.tif')
